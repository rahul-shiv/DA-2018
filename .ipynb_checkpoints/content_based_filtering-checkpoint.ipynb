# %%
#We will attempt to perform content based filtering using 1. overview and 2. Keywords, genres, cast and crew
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

meta = pd.read_csv("movies_metadata_preprocessed.csv")
print(meta['overview'].head())
meta['overview'] = meta['overview'].fillna('')

count = TfidfVectorizer(stop_words='english')
matrix = count.fit_transform(meta['overview'])
cosine_sim = linear_kernel(matrix, matrix)

indices = pd.Series(meta.index, index=meta['title']).drop_duplicates()
# Out:
# 0    Led by Woody, Andy's toys live happily in his ...
# 1    When siblings Judy and Peter discover an encha...
# 2    Cheated on, mistreated and stepped on, the wom...
# 3    Just when George Banks has recovered from his ...
# 4    Obsessive master thief, Neil McCauley leads a ...
# Name: overview, dtype: object

# %%
print(cosine_sim)
# Out:
# [[1.         0.01501598 0.         ... 0.         0.00593763 0.        ]
#  [0.01501598 1.         0.04686889 ... 0.         0.02199034 0.00927971]
#  [0.         0.04686889 1.         ... 0.         0.01404055 0.        ]
#  ...
#  [0.         0.         0.         ... 1.         0.         0.        ]
#  [0.00593763 0.02199034 0.01404055 ... 0.         1.         0.        ]
#  [0.         0.00927971 0.         ... 0.         0.         1.        ]]

# %%
def get_recommendations(title, cosine_sim=cosine_sim):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]
    movie_indices = [i[0] for i in sim_scores]
    return meta['title'].iloc[movie_indices]


rec = get_recommendations("The Conjuring")
print(rec)
# Out:
# 38020         The Conjuring 2
# 8087     The Boston Strangler
# 41622      Ghosts of Darkness
# 24885         The Borderlands
# 24041                   Ouija
# 39228       Chasing the Devil
# 19110          The Apparition
# 39115          Something Evil
# 16755               The Arbor
# 37937        8213: Gacy House
# Name: title, dtype: object

# %%
meta = pd.read_csv("movies_metadata_preprocessed.csv")
credits = pd.read_csv('../credits.csv')
meta = meta.merge(credits, on = 'id')
meta = meta.dropna(subset = ['cast', 'crew'])
print(meta)
# Out:
#            budget                                             genres      id  \
# 0      30000000.0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      65000000.0  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      24000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      16000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4      33500031.8                     [{'id': 35, 'name': 'Comedy'}]   11862
# 5      60000000.0  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...     949
# 6      58000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...   11860
# 7       4120000.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...   45325
# 8      35000000.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...    9091
# 9      58000000.0  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...     710
# 10     62000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...    9087
# 11      4768400.0  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...   12110
# 12     19800000.0  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...   21032
# 13     44000000.0  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...   10858
# 14     98000000.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...    1408
# 15     52000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...     524
# 16     16500000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...    4584
# 17      4000000.0  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...       5
# 18     30000000.0  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...    9273
# 19     60000000.0  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...   11517
# 20     30250000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 53, 'nam...    8012
# 21      9400000.0  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...    1710
# 22     50000000.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...    9691
# 23      6701002.4  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...   12665
# 24      3600000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...     451
# 25     19680000.0                      [{'id': 18, 'name': 'Drama'}]   16420
# 26     12000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...    9263
# 27     17493200.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   17015
# 28     18000000.0  [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...     902
# 29      7814000.0  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...   37557
# ...           ...                                                ...     ...
# 44012    740000.0                                                 []  325439
# 44013    215400.0  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...   63266
# 44014   6820000.0  [{'id': 28, 'name': 'Action'}, {'id': 9648, 'n...   45527
# 44015  16320000.0  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...  455661
# 44016   3003000.0                      [{'id': 18, 'name': 'Drama'}]  327237
# 44017    155686.0  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...   84710
# 44018   2260000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...   39562
# 44019  26960000.0                     [{'id': 35, 'name': 'Comedy'}]   14008
# 44020    154481.6  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...   49279
# 44021   1405571.0                    [{'id': 14, 'name': 'Fantasy'}]   44333
# 44022    620177.0  [{'id': 14, 'name': 'Fantasy'}, {'id': 35, 'na...   49277
# 44023     19660.0  [{'id': 14, 'name': 'Fantasy'}, {'id': 35, 'na...   49271
# 44024   1460000.0                                                 []   44324
# 44025   1119177.0                                                 []  122036
# 44026    753842.6  [{'id': 16, 'name': 'Animation'}, {'id': 10751...   14885
# 44027   1363384.6  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...   49280
# 44028   1460000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...  106807
# 44029    438400.0                [{'id': 99, 'name': 'Documentary'}]  276895
# 44030   5160000.0  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...  404604
# 44031    645400.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  420346
# 44032    696394.8                                                 []   67179
# 44033    739400.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...   84419
# 44034  10974100.0  [{'id': 9648, 'name': 'Mystery'}, {'id': 27, '...  390959
# 44035     36400.0                     [{'id': 27, 'name': 'Horror'}]  289923
# 44036   1247860.0           [{'id': 878, 'name': 'Science Fiction'}]  222848
# 44037   3683279.6  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...   30840
# 44038  40601000.0                      [{'id': 18, 'name': 'Drama'}]  111109
# 44039   1690000.0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 44040   1916000.0                                                 []  227506
# 44041    389400.0                                                 []  461257
#
#          imdb_id original_language  \
# 0      tt0114709                en
# 1      tt0113497                en
# 2      tt0113228                en
# 3      tt0114885                en
# 4      tt0113041                en
# 5      tt0113277                en
# 6      tt0114319                en
# 7      tt0112302                en
# 8      tt0114576                en
# 9      tt0113189                en
# 10     tt0112346                en
# 11     tt0112896                en
# 12     tt0112453                en
# 13     tt0113987                en
# 14     tt0112760                en
# 15     tt0112641                en
# 16     tt0114388                en
# 17     tt0113101                en
# 18     tt0112281                en
# 19     tt0113845                en
# 20     tt0113161                en
# 21     tt0112722                en
# 22     tt0112401                en
# 23     tt0114168                en
# 24     tt0113627                en
# 25     tt0114057                en
# 26     tt0114011                en
# 27     tt0114117                en
# 28     tt0112682                fr
# 29     tt0115012                zh
# ...          ...               ...
# 44012  tt0055178                en
# 44013  tt1489253                en
# 44014  tt1331329                en
# 44015  tt6969946                en
# 44016  tt3814486                nl
# 44017  tt0036975                en
# 44018  tt0889600                en
# 44019  tt0294425                en
# 44020  tt0000359                fr
# 44021  tt0135179                fr
# 44022  tt0135122                en
# 44023  tt0127948                en
# 44024  tt0135631                fr
# 44025  tt0224286                fr
# 44026  tt0457437                en
# 44027  tt0135453                fr
# 44028  tt0135571                fr
# 44029  tt3054038                en
# 44030  tt5690142                hi
# 44031  tt4130180                en
# 44032  tt0069215                it
# 44033  tt0038621                en
# 44034  tt0265736                en
# 44035  tt0252966                en
# 44036  tt0112613                en
# 44037  tt0102797                en
# 44038  tt2028550                tl
# 44039  tt0303758                en
# 44040  tt0008536                en
# 44041  tt6980792                en
#
#                                                 overview  popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...   21.946943
# 1      When siblings Judy and Peter discover an encha...   17.015539
# 2      A family wedding reignites the ancient feud be...   11.712900
# 3      Cheated on, mistreated and stepped on, the wom...    3.859495
# 4      Just when George Banks has recovered from his ...    8.387519
# 5      Obsessive master thief, Neil McCauley leads a ...   17.924927
# 6      An ugly duckling having undergone a remarkable...    6.677277
# 7      A mischievous young boy, Tom Sawyer, witnesses...    2.561161
# 8      International action superstar Jean Claude Van...    5.231580
# 9      James Bond must unmask the mysterious head of ...   14.686036
# 10     Widowed U.S. president Andrew Shepherd, one of...    6.318445
# 11     When a lawyer shows up at the vampire's doorst...    5.430331
# 12     An outcast half-wolf risks his life to prevent...   12.140733
# 13     An all-star cast powers this epic look at Amer...    5.092000
# 14     Morgan Adams and her slave, William Shaw, are ...    7.284477
# 15     The life of the gambling paradise – Las Vegas ...   10.137389
# 16     Rich Mr. Dashwood dies, leaving his second wif...   10.673167
# 17     It's Ted the Bellhop's first night on the job....    9.026586
# 18     Summoned from an ashram in Tibet, Ace finds hi...    8.205448
# 19     A vengeful New York transit cop decides to ste...    7.337906
# 20     Chili Palmer is a Miami mobster who gets sent ...   12.669608
# 21     An agoraphobic psychologist and a female detec...   10.701801
# 22     Assassin Robert Rath arrives at a funeral to k...   11.065939
# 23     Harassed by classmates who won't accept his sh...   12.133094
# 24     Ben Sanderson, an alcoholic Hollywood screenwr...   10.332025
# 25     The evil Iago pretends to be friend of Othello...    1.845899
# 26     Waxing nostalgic about the bittersweet passage...    8.681325
# 27     This film adaptation of Jane Austen's last nov...    2.228434
# 28     A scientist in a surrealist society kidnaps ch...    9.822423
# 29     A provincial boy related to a Shanghai crime f...    1.100915
# ...                                                  ...         ...
# 44012  Young Aladdin (Donald O'Connor) has a series o...    0.093498
# 44013  Rainy summer evening... Young people are arriv...    0.643625
# 44014  A stranger named Silas flees from a devastatin...    1.270832
# 44015  A closeted boy runs the risk of being outed by...   20.821780
# 44016  Bloed, Zweet en Tranen (Blood, Sweat and Tears...    0.590087
# 44017  Paula the ape woman (Acquanetta) is alive and ...    0.143223
# 44018  Pretty, popular, and slim high-schooler Aly Sc...    0.767762
# 44019  Hyperactive teenager Kelly is enrolled into a ...    4.392389
# 44020  A chemist in his laboratory places upon a tabl...    1.618458
# 44021  A bearded magician holds up a large playing ca...    0.208349
# 44022  A wall full of advertising posters comes to life.    0.148131
# 44023  A man rents an apartment and furnishes it in r...    0.725084
# 44024  The background of this picture represents a sc...    0.213973
# 44025  This shows a prince entering upon the stage of...    0.071782
# 44026  It's Halloween in the 100 Acre Wood, and Roo's...    2.568495
# 44027  A band-leader has arranged seven chairs for th...    1.109068
# 44028         A series of fantastical wrestling matches.    0.225432
# 44029  Deep Hearts is a film about the Bororo Fulani,...    0.011025
# 44030  The bliss of a biology teacher’s family life i...    1.559596
# 44031  The Morning After is a feature film that consi...    0.139936
# 44032  Sentenced to life imprisonment for illegal act...    0.225051
# 44033  An unsuccessful sculptor saves a madman named ...    0.222814
# 44034  In this true-crime documentary, we delve into ...    0.076061
# 44035  A film archivist revisits the story of Rustin ...    0.386450
# 44036  It's the year 3000 AD. The world's most danger...    0.661558
# 44037  Yet another version of the classic epic, with ...    5.683753
# 44038  An artist struggles to finish his work while a...    0.178241
# 44039  When one of her hits goes wrong, a professiona...    0.903007
# 44040  In a small town live two brothers, one a minis...    0.003503
# 44041  50 years after decriminalisation of homosexual...    0.163015
#
#                                     production_companies release_date  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]   1995-10-30
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...   1995-12-15
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...   1995-12-22
# 3      [{'name': 'Twentieth Century Fox Film Corporat...   1995-12-22
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...   1995-02-10
# 5      [{'name': 'Regency Enterprises', 'id': 508}, {...   1995-12-15
# 6      [{'name': 'Paramount Pictures', 'id': 4}, {'na...   1995-12-15
# 7            [{'name': 'Walt Disney Pictures', 'id': 2}]   1995-12-22
# 8      [{'name': 'Universal Pictures', 'id': 33}, {'n...   1995-12-22
# 9      [{'name': 'United Artists', 'id': 60}, {'name'...   1995-11-16
# 10     [{'name': 'Columbia Pictures', 'id': 5}, {'nam...   1995-11-17
# 11     [{'name': 'Columbia Pictures', 'id': 5}, {'nam...   1995-12-22
# 12     [{'name': 'Universal Pictures', 'id': 33}, {'n...   1995-12-22
# 13     [{'name': 'Hollywood Pictures', 'id': 915}, {'...   1995-12-22
# 14     [{'name': 'Le Studio Canal+', 'id': 183}, {'na...   1995-12-22
# 15     [{'name': 'Universal Pictures', 'id': 33}, {'n...   1995-11-22
# 16     [{'name': 'Columbia Pictures Corporation', 'id...   1995-12-13
# 17     [{'name': 'Miramax Films', 'id': 14}, {'name':...   1995-12-09
# 18     [{'name': 'O Entertainment', 'id': 5682}, {'na...   1995-11-10
# 19              [{'name': 'Columbia Pictures', 'id': 5}]   1995-11-21
# 20     [{'name': 'Jersey Films', 'id': 216}, {'name':...   1995-10-20
# 21     [{'name': 'Regency Enterprises', 'id': 508}, {...   1995-10-27
# 22     [{'name': 'Silver Pictures', 'id': 1885}, {'na...   1995-10-06
# 23     [{'name': 'Caravan Pictures', 'id': 175}, {'na...   1995-10-27
# 24     [{'name': 'United Artists', 'id': 60}, {'name'...   1995-10-27
# 25     [{'name': 'Columbia Pictures', 'id': 5}, {'nam...   1995-12-15
# 26               [{'name': 'New Line Cinema', 'id': 12}]   1995-10-20
# 27                    [{'name': 'BBC Films', 'id': 288}]   1995-09-27
# 28     [{'name': 'Procirep', 'id': 311}, {'name': 'Co...   1995-05-16
# 29     [{'name': 'Ministère des Affaires Étrangères',...   1995-04-30
# ...                                                  ...          ...
# 44012                                                 []   1961-10-31
# 44013  [{'name': 'Art Pictures Studio', 'id': 3451}, ...   2010-03-25
# 44014  [{'name': 'Boll Kino Beteiligungs GmbH & Co. K...   2010-01-01
# 44015  [{'name': 'Ringling College of Art and Design'...   2017-06-01
# 44016                                                 []   2015-04-02
# 44017         [{'name': 'Universal Pictures', 'id': 33}]   1944-06-01
# 44018                                                 []   2007-01-08
# 44019  [{'name': 'Walt Disney Television', 'id': 670}...   2002-03-07
# 44020       [{'name': 'Star Film Company', 'id': 45867}]   1901-01-01
# 44021                [{'name': 'Star-Film', 'id': 7159}]   1905-01-01
# 44022  [{'name': 'Star-Film', 'id': 7159}, {'name': '...   1906-01-01
# 44023       [{'name': 'Star Film Company', 'id': 45867}]   1909-01-01
# 44024       [{'name': 'Star Film Company', 'id': 45867}]   1904-03-05
# 44025       [{'name': 'Star Film Company', 'id': 45867}]   1904-01-01
# 44026        [{'name': 'Walt Disney Pictures', 'id': 2}]   2005-09-13
# 44027       [{'name': 'Star Film Company', 'id': 45867}]   1900-01-01
# 44028                [{'name': 'Star-Film', 'id': 7159}]   1900-01-01
# 44029                                                 []   1981-01-01
# 44030  [{'name': 'Mad Films', 'id': 82459}, {'name': ...   2017-07-07
# 44031  [{'name': 'Oops Doughnuts Productions', 'id': ...   2015-01-11
# 44032                                                 []   1972-01-01
# 44033         [{'name': 'Universal Pictures', 'id': 33}]   1946-03-29
# 44034                                                 []   2000-10-22
# 44035  [{'name': 'Neptune Salad Entertainment', 'id':...   2000-10-03
# 44036    [{'name': 'Concorde-New Horizons', 'id': 4688}]   1995-01-01
# 44037  [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...   1991-05-13
# 44038             [{'name': 'Sine Olivia', 'id': 19653}]   2011-11-17
# 44039  [{'name': 'American World Pictures', 'id': 6165}]   2003-08-01
# 44040               [{'name': 'Yermoliev', 'id': 88753}]   1917-10-21
# 44041                                                 []   2017-06-09
#
#            revenue  runtime                             title  vote_average  \
# 0      373554033.0     81.0                         Toy Story           7.7
# 1      262797249.0    104.0                           Jumanji           6.9
# 2       21701232.8    101.0                  Grumpier Old Men           6.5
# 3       81452156.0    127.0                 Waiting to Exhale           6.1
# 4       76578911.0    106.0       Father of the Bride Part II           5.7
# 5      187436818.0    170.0                              Heat           7.7
# 6       76574768.0    127.0                           Sabrina           6.2
# 7        8994871.8     97.0                      Tom and Huck           5.4
# 8       64350171.0    106.0                      Sudden Death           5.5
# 9      352194034.0    130.0                         GoldenEye           6.6
# 10     107879496.0    106.0            The American President           6.5
# 11        159572.6     88.0       Dracula: Dead and Loving It           5.7
# 12      11348324.0     78.0                             Balto           7.1
# 13      13681765.0    192.0                             Nixon           7.1
# 14      10017322.0    119.0                  Cutthroat Island           5.7
# 15     116112375.0    178.0                            Casino           7.8
# 16     135000000.0    136.0             Sense and Sensibility           7.2
# 17       4300000.0     98.0                        Four Rooms           6.5
# 18     212385533.0     90.0    Ace Ventura: When Nature Calls           6.1
# 19      35431113.0    103.0                       Money Train           5.4
# 20     115101622.0    105.0                        Get Shorty           6.4
# 21      14229662.4    124.0                           Copycat           6.5
# 22      30303072.0    132.0                         Assassins           6.0
# 23      10285951.0    111.0                            Powder           6.3
# 24      49800000.0    112.0                 Leaving Las Vegas           7.1
# 25      10593971.2    123.0                           Othello           7.0
# 26      27400000.0    100.0                      Now and Then           6.6
# 27      20019097.6    104.0                        Persuasion           7.4
# 28       1738611.0    108.0         The City of Lost Children           7.6
# 29       5215470.0    108.0                    Shanghai Triad           6.5
# ...            ...      ...                               ...           ...
# 44012    4153103.8     93.0            The Wonders of Aladdin           0.0
# 44013    4836920.0     79.0                Phobos. Fear Kills           3.0
# 44014     933888.8     92.0                   The Final Storm           3.7
# 44015    8905199.6      4.0                    In a Heartbeat           8.3
# 44016    9418702.8    111.0            Blood, Sweat and Tears           6.8
# 44017    7903507.2     61.0                      Jungle Woman           5.8
# 44018    3215200.6     89.0                 To Be Fat Like Me           5.0
# 44019   24036605.8    101.0                       Cadet Kelly           5.2
# 44020    5329523.0      3.0      The Man with the Rubber Head           7.6
# 44021    5143378.0      3.0          The Living Playing Cards           6.1
# 44022    1324010.8      3.0             The Hilarious Posters           4.5
# 44023     351850.4      6.0               The Devilish Tenant           6.7
# 44024   39170887.0      3.0           The Untameable Whiskers           6.0
# 44025    2193281.6      2.0  The Imperceptable Transmutations           5.0
# 44026    4696190.6     67.0  Pooh's Heffalump Halloween Movie           5.4
# 44027    4279336.8      1.0                  The One-Man Band           6.5
# 44028   39170887.0      2.0  The Fat and Lean Wrestling Match           6.5
# 44029    2008552.4     58.0                       Deep Hearts           0.0
# 44030     455306.0    146.0                               Mom           6.6
# 44031   19036652.0     79.0                 The Morning After           4.0
# 44032    1092991.8     90.0         St. Michael Had a Rooster           6.0
# 44033    3353103.8     65.0                  House of Horrors           6.3
# 44034    9736395.8     45.0         Shadow of the Blair Witch           7.0
# 44035    1066648.0     30.0               The Burkittsville 7           7.0
# 44036   13011299.4     85.0                   Caged Heat 3000           3.5
# 44037    1027200.0    104.0                        Robin Hood           5.7
# 44038   68881053.0    360.0               Century of Birthing           9.0
# 44039    1335488.0     90.0                          Betrayal           3.8
# 44040    3720018.6     87.0                  Satan Triumphant           0.0
# 44041    2563015.2     75.0                          Queerama           0.0
#
#        vote_count                                           keywords  \
# 0          5415.0  ['jealousy', 'toy', 'boy', 'friendship', 'frie...
# 1          2413.0  ['board game', 'disappearance', "based on chil...
# 2            92.0  ['fishing', 'best friend', 'duringcreditssting...
# 3            34.0  ['based on novel', 'interracial relationship',...
# 4           173.0  ['baby', 'midlife crisis', 'confidence', 'agin...
# 5          1886.0  ['robbery', 'detective', 'bank', 'obsession', ...
# 6           141.0  ['paris', 'brother brother relationship', 'cha...
# 7            45.0  ['terrorist', 'hostage', 'explosive', 'vice pr...
# 8           174.0  ['cuba', 'falsely accused', 'secret identity',...
# 9          1194.0  ['white house', 'usa president', 'new love', '...
# 10          199.0                               ['dracula', 'spoof']
# 11          210.0  ['wolf', 'dog-sledding race', 'alaska', 'dog',...
# 12          423.0  ['usa president', 'presidential election', 'wa...
# 13           72.0  ['exotic island', 'treasure', 'map', 'ship', '...
# 14          137.0  ['poker', 'drug abuse', '1970s', 'overdose', '...
# 15         1343.0  ['bowling', 'based on novel', 'servant', 'coun...
# 16          364.0  ['hotel', "new year's eve", 'witch', 'bet', 'h...
# 17          539.0  ['africa', 'indigenous', 'human animal relatio...
# 18         1128.0  ['brother brother relationship', 'subway', 'ne...
# 19          224.0  ['gambling', 'miami', 'based on novel', 'job',...
# 20          305.0  ['police brutality', 'psychology', 'police ope...
# 21          199.0  ['competition', 'assassination', 'cia', 'bank'...
# 22          394.0  ['dead animal', 'shot to death', 'teenage boy'...
# 23          143.0  ['individual', 'prostitute', 'alcohol', 'casin...
# 24          365.0      ['shakespeare', 'jealousy', 'friend', 'moor']
# 25           33.0  ['1970s', 'female friendship', 'coming of age'...
# 26           91.0  ['captain', 'napoleonic wars', 'old flame', 'a...
# 27           36.0  ['clone', 'dream', 'island', 'eye', 'dystopia'...
# 28          308.0  ['servant', 'cabaret', 'shanghai', 'diva', 'un...
# 29           17.0  ['rap music', 'karate', 'high school', 'naval ...
# ...           ...                                                ...
# 44012         0.0             ['admiration', 'curiosity', 'aladdin']
# 44013         2.0                        ['care', 'fear', 'killing']
# 44014        11.0           ['final exam', 'storm', 'violent storm']
# 44015       146.0                                ['indiana', 'wink']
# 44016        11.0  ['sweat', 'sweat', 'crying', 'rent', 'tears', ...
# 44017         2.0  ['jungle', 'woman', 'womanhood', 'cleaning lady']
# 44018        12.0                                          ['maine']
# 44019       145.0                                          ['cadet']
# 44020        29.0  ['human being', 'isle of man', 'human', 'man',...
# 44021         8.0  ['animation', 'support', 'life', 'acting', 'ci...
# 44022         2.0                                 ['card', 'poster']
# 44023        12.0                                         ['tenant']
# 44024         6.0                                  ['beard', 'hair']
# 44025         2.0                                 ['transformation']
# 44026         7.0                   ['halloween', 'film', 'picture']
# 44027        22.0              ['band', 'dance band', 'ring', 'set']
# 44028         6.0  ['list', 'wrestling', 'match', 'lucifer', 'cou...
# 44029         0.0  ['spirit', 'eye', 'substance', 'meat', 'affect...
# 44030        14.0                                          ['mummy']
# 44031         2.0                     ['morning', 'sunrise', 'dawn']
# 44032         3.0                                        ['rooster']
# 44033         8.0  ['house', 'household', 'sign', 'home', 'firm',...
# 44034         2.0  ['shadow', 'phantom', 'dark', 'darkness', 'tai...
# 44035         1.0                                                NaN
# 44036         1.0                                ['passion', 'heat']
# 44037        26.0  ['robin', 'hood', 'thug', 'goon', 'punk', 'hoo...
# 44038         3.0               ['century', 'giving birth', 'birth']
# 44039         6.0               ['betrayal', 'treason', 'treachery']
# 44040         0.0                      ['satan', 'lucifer', 'devil']
# 44041         0.0                                                NaN
#
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# 5      [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 6      [{'cast_id': 1, 'character': 'Linus Larrabee',...
# 7      [{'cast_id': 2, 'character': 'Tom Sawyer', 'cr...
# 8      [{'cast_id': 1, 'character': 'Darren Francis T...
# 9      [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 10     [{'cast_id': 1, 'character': 'Andrew Shepherd'...
# 11     [{'cast_id': 9, 'character': 'Count Dracula', ...
# 12     [{'cast_id': 1, 'character': 'Balto (voice)', ...
# 13     [{'cast_id': 1, 'character': 'Richard Nixon', ...
# 14     [{'cast_id': 1, 'character': 'Morgan Adams', '...
# 15     [{'cast_id': 4, 'character': "Sam 'Ace' Rothst...
# 16     [{'cast_id': 6, 'character': 'Marianne Dashwoo...
# 17     [{'cast_id': 42, 'character': 'Ted the Bellhop...
# 18     [{'cast_id': 1, 'character': 'Ace Ventura', 'c...
# 19     [{'cast_id': 1, 'character': 'John', 'credit_i...
# 20     [{'cast_id': 1, 'character': 'Chili Palmer', '...
# 21     [{'cast_id': 8, 'character': 'Helen Hudson', '...
# 22     [{'cast_id': 1, 'character': 'Robert Rath', 'c...
# 23     [{'cast_id': 1, 'character': 'Jessie Caldwell'...
# 24     [{'cast_id': 1, 'character': 'Ben Sanderson', ...
# 25     [{'cast_id': 2, 'character': 'Othello', 'credi...
# 26     [{'cast_id': 9, 'character': 'Young Roberta Ma...
# 27     [{'cast_id': 1, 'character': 'Anne Elliott', '...
# 28     [{'cast_id': 24, 'character': 'One', 'credit_i...
# 29     [{'cast_id': 2, 'character': 'Xiao Jingbao', '...
# ...                                                  ...
# 44012  [{'cast_id': 2, 'character': 'Aladdin', 'credi...
# 44013  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 44014  [{'cast_id': 1, 'character': 'Gillian Grady', ...
# 44015                                                 []
# 44016  [{'cast_id': 2, 'character': 'André Hazes', 'c...
# 44017  [{'cast_id': 2, 'character': 'Paula Dupree - t...
# 44018  [{'cast_id': 1, 'character': 'Alyson', 'credit...
# 44019  [{'cast_id': 1, 'character': 'Kelly Collins', ...
# 44020  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 44021  [{'cast_id': 2, 'character': 'The Magician', '...
# 44022  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 44023  [{'cast_id': 2, 'character': 'Le Concierge', '...
# 44024  [{'cast_id': 2, 'character': 'Man with whisker...
# 44025                                                 []
# 44026  [{'cast_id': 1, 'character': 'Roo (voice)', 'c...
# 44027  [{'cast_id': 3, 'character': 'All the members ...
# 44028  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 44029                                                 []
# 44030  [{'cast_id': 1, 'character': 'Devki Sabarwal',...
# 44031  [{'cast_id': 0, 'character': 'Lauren', 'credit...
# 44032  [{'cast_id': 5, 'character': '', 'credit_id': ...
# 44033  [{'cast_id': 5, 'character': 'The Creeper', 'c...
# 44034  [{'cast_id': 30, 'character': 'Debuty Hank Har...
# 44035  [{'cast_id': 2, 'character': 'Branwall', 'cred...
# 44036  [{'cast_id': 1, 'character': 'Kira (as Cassand...
# 44037  [{'cast_id': 1, 'character': 'Sir Robert Hode'...
# 44038  [{'cast_id': 1002, 'character': 'Sister Angela...
# 44039  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 44040  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 44041                                                 []
#
#                                                     crew
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# 5      [{'credit_id': '52fe4292c3a36847f802916d', 'de...
# 6      [{'credit_id': '52fe44959251416c75039da9', 'de...
# 7      [{'credit_id': '52fe46bdc3a36847f810f797', 'de...
# 8      [{'credit_id': '52fe44dbc3a36847f80ae0f1', 'de...
# 9      [{'credit_id': '52fe426ec3a36847f801e14b', 'de...
# 10     [{'credit_id': '52fe44dac3a36847f80adfa3', 'de...
# 11     [{'credit_id': '52fe44b79251416c7503e7fb', 'de...
# 12     [{'credit_id': '593f24b9c3a3680369002371', 'de...
# 13     [{'credit_id': '52fe43c59251416c7501d6f3', 'de...
# 14     [{'credit_id': '52fe42f4c3a36847f802f69f', 'de...
# 15     [{'credit_id': '52fe424dc3a36847f80139cd', 'de...
# 16     [{'credit_id': '52fe43cec3a36847f807101f', 'de...
# 17     [{'credit_id': '52fe420dc3a36847f800011b', 'de...
# 18     [{'credit_id': '52fe44dfc3a36847f80af28b', 'de...
# 19     [{'credit_id': '52fe44509251416c750305a1', 'de...
# 20     [{'credit_id': '52fe448dc3a36847f809c729', 'de...
# 21     [{'credit_id': '52fe430ec3a36847f803722d', 'de...
# 22     [{'credit_id': '52fe451cc3a36847f80bd145', 'de...
# 23     [{'credit_id': '52fe45129251416c7504ab67', 'de...
# 24     [{'credit_id': '52fe4245c3a36847f80111c3', 'de...
# 25     [{'credit_id': '5462510ec3a368082d000121', 'de...
# 26     [{'credit_id': '52fe44dec3a36847f80aed45', 'de...
# 27     [{'credit_id': '52fe46ff9251416c7508a8b3', 'de...
# 28     [{'credit_id': '52fe428ac3a36847f8026c6f', 'de...
# 29     [{'credit_id': '52fe46559251416c910511c9', 'de...
# ...                                                  ...
# 44012  [{'credit_id': '54df54e5925141195a0033cb', 'de...
# 44013  [{'credit_id': '52fe46a2c3a368484e09b639', 'de...
# 44014  [{'credit_id': '52fe46c7c3a36847f81119a1', 'de...
# 44015  [{'credit_id': '5981a15c92514151e0011b51', 'de...
# 44016  [{'credit_id': '54edb0e0c3a3686d58003a13', 'de...
# 44017  [{'credit_id': '52fe49099251416c910a0a89', 'de...
# 44018  [{'credit_id': '562ec44ec3a3681b5900bac2', 'de...
# 44019  [{'credit_id': '52fe45c29251416c75061803', 'de...
# 44020  [{'credit_id': '52fe478dc3a36847f813bd5f', 'de...
# 44021  [{'credit_id': '52fe4684c3a36847f810350b', 'de...
# 44022  [{'credit_id': '52fe478dc3a36847f813bd4b', 'de...
# 44023  [{'credit_id': '52fe478dc3a36847f813bd19', 'de...
# 44024  [{'credit_id': '52fe4684c3a36847f810345f', 'de...
# 44025  [{'credit_id': '52fe4a74c3a368484e1542e9', 'de...
# 44026  [{'credit_id': '52fe46249251416c7506e969', 'de...
# 44027  [{'credit_id': '52fe478dc3a36847f813bd6b', 'de...
# 44028  [{'credit_id': '52fe4a71c3a36847f81ce35b', 'de...
# 44029  [{'credit_id': '539ef1090e0a263dd00000d7', 'de...
# 44030  [{'credit_id': '58ee55bbc3a3683df500bd0f', 'de...
# 44031  [{'credit_id': '587626f4c3a3682b33008299', 'de...
# 44032  [{'credit_id': '5330178a9251413a720055e3', 'de...
# 44033  [{'credit_id': '58152c139251415a7f0047e2', 'de...
# 44034  [{'credit_id': '56ff6ddbc3a3686e9e0013bc', 'de...
# 44035  [{'credit_id': '5403d669c3a3682d9800427d', 'de...
# 44036  [{'credit_id': '5757f36ac3a3687d6f000e8a', 'de...
# 44037  [{'credit_id': '52fe44439251416c9100a899', 'de...
# 44038  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...
# 44039  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...
# 44040  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...
# 44041  [{'credit_id': '593e676c92514105b702e68e', 'de...
#
# [44042 rows x 17 columns]

# %%
from ast import literal_eval
print(type(meta['cast'][0]))
print(type(meta['crew'][0]))
print(type(meta['keywords'][0]))
print(type(meta['genres'][0]))
meta = meta.dropna(subset = ['keywords'])
meta = meta.dropna(subset = ['genres'])

# for i,row in meta.iterrows():
# #     meta['keywords'][i] = literal_eval(meta['keywords'][i])
#     print(meta['keywords'][i])
#     print(type(meta['keywords'][i]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
#Content based filtering using keywords, genres, cast and crew
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from ast import literal_eval


features = ['cast','crew','keywords', 'genres']

for feature in features:
    meta[feature] = meta[feature].apply(literal_eval)

# %%
import numpy as np
def get_director(x):
    for i in x:
        if i['job'] == 'Director':
            return i['name']
    return np.nan

def get_list(x):
    if isinstance(x, list):
        names = [i for i in x]
        if len(names) > 3:
            names = names[:3]
        return names
    
    return []
def get_list1(x):
    if isinstance(x, dict):
        names = [i['name'] for i in x]
        print(names)
        if len(names) > 3:
            names = names[:3]
        return names
    return []

def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''

meta['director'] = meta['crew'].apply(get_director)

features = ['cast', 'keywords']

for feature in features:
    meta[feature] = meta[feature].apply(get_list)
    
meta['genres']=meta['genres'].apply(get_list1)
    
features = ['cast', 'keywords', 'director', 'genres']

for feature in features:
    meta[feature] = meta[feature].apply(clean_data)
    print(feature)
    
def combine(x):
    return ' '.join(x['keywords']) + ' ' + ' '.join(x['cast']) + ' ' + x['director'] + ' ' + ' '.join(x['genres'])
meta['combined'] = meta.apply(combine, axis=1)


count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(meta['combined'])

cosine_sim2 = cosine_similarity(count_matrix, count_matrix)

meta = meta.reset_index()
indices = pd.Series(meta.index, index=meta['title'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-ad01bb05baa7> in <module>()
#      44
#      45 for feature in features:
# ---> 46     meta[feature] = meta[feature].apply(clean_data)
#      47     print(feature)
#      48
#
# /Users/rahulshiv/anaconda/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-9-ad01bb05baa7> in clean_data(x)
#      25 def clean_data(x):
#      26     if isinstance(x, list):
# ---> 27         return [str.lower(i.replace(" ", "")) for i in x]
#      28     else:
#      29         if isinstance(x, str):
#
# <ipython-input-9-ad01bb05baa7> in <listcomp>(.0)
#      25 def clean_data(x):
#      26     if isinstance(x, list):
# ---> 27         return [str.lower(i.replace(" ", "")) for i in x]
#      28     else:
#      29         if isinstance(x, str):
#
# AttributeError: 'dict' object has no attribute 'replace'

# %%
get_recommendations('The Conjuring', cosine_sim2)
